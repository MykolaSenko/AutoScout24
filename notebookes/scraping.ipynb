# %% [markdown]
# Importing dependencies

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json

# %% [markdown]
# Scraping number of cars which are available on autoscout24.

# %%
url = "https://www.autoscout24.be/nl/lst?atype=C&cy=B&desc=0&sort=standard&source=homepage_search-mask&ustate=N%2CU"

response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")


print(soup.prettify())

print(response.status_code)
# Out:
# <!DOCTYPE html>
# <html lang="nl-BE">
#  <head>
#   <meta charset="utf-8"/>
#   <link href="https://prod.pictures.autoscout24.net" rel="preconnect"/>
#   <link as="style" href="/assets/as24-search-funnel/_next/static/css/ce010c4c5ea90695.css" rel="preload"/>
#   <link as="style" href="/assets/as24-search-funnel/_next/static/css/274b860b6c1285c8.css" rel="preload"/>
#   <link as="style" href="/assets/as24-search-funnel/_next/static/css/ae8e2452880e7c8d.css" rel="preload"/>
#   <link as="script" href="/assets/as24-search-funnel/_next/static/chunks/7917.44701ba9472f9154.js" rel="preload"/>
#   <link as="script" href="/assets/as24-search-funnel/_next/static/chunks/webpack-01874695f39849a6.js" rel="preload"/>
#   <link as="script" href="/assets/as24-search-funnel/_next/static/chunks/framework-ce84985cd166733a.js" rel="preload"/>
#   <link as="script" href="/assets/as24-search-funnel/_next/static/chunks/main-22756128e78df9fc.js" rel="preload"/>
# ...

# %% [markdown]
# Extracting values from json data.

# %%
script_tag = soup.find(id="__NEXT_DATA__")
if script_tag:
    # Extract the text content from the script tag
    script_content = script_tag.string

    # Parse the JSON data
    data = json.loads(script_content)

    # Access the numberOfResults property
    try:
        number_of_results = data['props']['pageProps']['numberOfResults']
        print(f"There are {number_of_results} cars for sale in Belgium.")  
    except KeyError as e:
        print(f"Error: {e}")
else:
    print("Script tag with ID '__NEXT_DATA__' not found.")
# Out:
# There are 118117 cars for sale in Belgium.

# %% [markdown]
# Opening the excell file with the brand data.

# %%
brands_file_path = '../data/cars_brands.xlsx'
df_brands = pd.read_excel(brands_file_path)
brands_list = df_brands.values.tolist()
brands = [item for sublist in brands_list for item in sublist]
brands = [brand.lower() for brand in brands]
brands = [brand.replace("\xa0", "-") for brand in brands]
print(brands)
print(len(brands))
# Out:
# ['bmw', 'audi', 'volkswagen', 'porsche', 'mini', 'ford', 'toyota', 'volvo', 'peugeot', '9ff', 'abarth', 'ac', 'acm', 'acura', 'aiways', 'aixam', 'alba-mobility', 'alfa-romeo', 'alpina', 'alpine', 'amphicar', 'angelelli-automobili', 'ariel-motor', 'artega', 'aspark', 'aspid', 'aston-martin', 'aurus', 'austin', 'austin-healey', 'autobianchi', 'baic', 'bedford', 'bellier', 'bentley', 'boldmen', 'bolloré', 'borgward', 'brilliance', 'bristol', 'bugatti', 'buick', 'byd', 'cadillac', 'caravans-wohnm', 'carver', 'casalini', 'caterham', 'cenntro', 'changhe', 'chatenet', 'chery', 'chevrolet', 'chrysler', 'citroen', 'cityel', 'corvette', 'cupra', 'dacia', 'daewoo', 'daf', 'daihatsu', 'daimler', 'dallara', 'dangel', 'de-la-chapelle', 'de-tomaso', 'delorean', 'devinci-cars', 'dfsk', 'dodge', 'donkervoort', 'dr-automobiles', 'ds-automobiles', 'dutton', 'e.go', 'econelo', 'edran', 'elaris', 'embuggy', 'emc', 'estrima', 'evetta', 'evo', 'ferrari', 'fiat', 'fisker', 'gac-gonow', 'galloper', 'gappy', 
# ...

# %% [markdown]
# Opening csv file with zipcodes.

# %%
zipcode_file_path = '../data/zipcode-belgium.csv'
df_zipcodes = pd.read_csv(zipcode_file_path)

display(df_zipcodes)
# Out:
#       postcode           locality       lat       long
# 0         1000          Bruxelles  4.351697  50.846557
# 1         1020             Laeken  4.348713  50.883392
# 2         1030         Schaerbeek  4.373712  50.867604
# 3         1040          Etterbeek  4.389510  50.836851
# 4         1050            Ixelles  4.381571  50.822285
# ...        ...                ...       ...        ...
# 2752      9988  Waterland-Oudeman  3.590549  51.289118
# 2753      9988         Watervliet  3.626982  51.277650
# 2754      9990           Maldegem  3.415454  51.226313
# 2755      9991             Adegem  3.485847  51.203529
# 2756      9992         Middelburg  3.407143  51.255832
#
# [2757 rows x 4 columns]

# %% [markdown]
# Creating lists from zipcodes  dataframe.

# %%
list_zipcodes = df_zipcodes['postcode'].tolist()
print(list_zipcodes)
print(len(list_zipcodes))

list_cities = df_zipcodes['locality'].tolist()
print(list_cities)
print(len(list_cities))

list_lat = df_zipcodes['long'].tolist()
print(list_lat)
print(len(list_lat))

list_long = df_zipcodes['lat'].tolist()
print(list_long)
print(len(list_long))
# Out:
# [1000, 1020, 1030, 1040, 1050, 1060, 1070, 1080, 1081, 1082, 1083, 1090, 1120, 1130, 1140, 1150, 1160, 1170, 1180, 1190, 1200, 1210, 1300, 1300, 1301, 1310, 1315, 1315, 1315, 1315, 1315, 1320, 1320, 1320, 1320, 1320, 1325, 1325, 1325, 1325, 1325, 1330, 1331, 1332, 1340, 1340, 1341, 1342, 1348, 1350, 1350, 1350, 1350, 1350, 1350, 1350, 1350, 1357, 1357, 1357, 1357, 1360, 1360, 1360, 1360, 1360, 1367, 1367, 1367, 1367, 1367, 1367, 1367, 1370, 1370, 1370, 1370, 1370, 1370, 1370, 1370, 1370, 1370, 1380, 1380, 1380, 1380, 1380, 1380, 1390, 1390, 1390, 1390, 1390, 1400, 1400, 1401, 1402, 1404, 1410, 1420, 1421, 1428, 1430, 1430, 1430, 1430, 1435, 1435, 1435, 1440, 1440, 1450, 1450, 1450, 1450, 1450, 1457, 1457, 1457, 1457, 1460, 1460, 1461, 1470, 1470, 1470, 1471, 1472, 1473, 1474, 1476, 1480, 1480, 1480, 1480, 1490, 1495, 1495, 1495, 1495, 1495, 1500, 1501, 1502, 1540, 1540, 1541, 1547, 1560, 1570, 1570, 1570, 1600, 1600, 1600, 1601, 1602, 1620, 1630, 1640, 1650, 1651, 1652, 1653, 1654, 1
# ...

# %% [markdown]
# Generating link for scraping

# %%
for brand in brands:
    for zipcode, city, lat, lon in zip(list_zipcodes, list_cities, list_lat, list_long):
        page = 1
        while True:
            url_scr = f"https://www.autoscout24.be/nl/lst/{brand}/{zipcode}-{city}?atype=C&cy=B&damaged_listing=exclude&desc=0&lat={lat}&lon={lon}&page={page}&powertype=kw&search_id=1mqvtm8cw4&sort=standard&source=homepage_search-mask&ustate=N%2CU&zipr=10"
            response = requests.get(url_scr)
            soup_page = BeautifulSoup(response.content, "lxml")
            cars_amount = soup_page.find(class_='ListHeader_headerTitle__Hkaeg').find('span').find('span').text
            
            if cars_amount == "0":
                print(f"No cars of {brand} were found in {zipcode}{city}")
                
                
            else:
                print(f"There are {cars_amount} cars of {brand} for sale in {zipcode}{city}")
                pages_amount = soup_page.find(class_='pagination-item--disabled pagination-item--page-indicator').text
                pages = pages_amount[4:]
                print(pages)

                for page in range(1, int(pages) + 1):
                print(page)
            
                script_tag = soup.find(id="__NEXT_DATA__")
                if script_tag:
                
                    script_content = script_tag.string

                    # Parse the JSON data
                    data = json.loads(script_content)

                    # Access the numberOfResults property
                    try:
                        number_of_results = data['props']['pageProps']['numberOfResults']
                        print(f"There are {number_of_results} cars for sale in Belgium.")  
                    except KeyError as e:
                        print(f"Error: {e}")
                else:
                    print("Script tag with ID '__NEXT_DATA__' not found.")
                    page += 1
                    if page == 2:
                        break
    



"""
brand = "aspark"
zipcode = 1000
city = "brussels"
lat = 50.846557
lon = 4.351697
page = 1
"""

# %% [markdown]
# Scraping brands on specific locations

# %%
print(url_scr)
response = requests.get(url_scr)

soup_page = BeautifulSoup(response.content, "lxml")
# Out:
# https://www.autoscout24.be/nl/lst/aspark/1000-brussels?atype=C&cy=B&damaged_listing=exclude&desc=0&lat=50.846557&lon=4.351697&page=1&powertype=kw&search_id=1mqvtm8cw4&sort=standard&source=homepage_search-mask&ustate=N%2CU&zipr=10

# %%
cars_amount = soup_page.find(class_='ListHeader_headerTitle__Hkaeg').find('span').find('span').text
print(cars_amount)


if cars_amount == "0":
    print("No cars found")
else:
    
    pages_amount = soup_page.find(class_='pagination-item--disabled pagination-item--page-indicator').text
    

    pages = pages_amount[4:]
    print(pages)

    for page in range(1, int(pages) + 1):
        
        print(page)
# Out:
# 0
# No cars found

# %%
"""


brands_tags = soup.find_all(class_="scr-chip")

brands = []
for brands_tag in brands_tags:
    brands.append(brands_tag.text)
print(brands)
brands = set(brands)
brands = list(brands)

print(brands)

brands_clean = []
for brand in brands:
    brand = brand[:-1]
    brand = brand.lower()
    brands_clean.append(brand)
del brands[0]
print(brands_clean)
    
"""
# Out:
# '\n\n\nbrands_tags = soup.find_all(class_="scr-chip")\n\nbrands = []\nfor brands_tag in brands_tags:\n    brands.append(brands_tag.text)\nprint(brands)\nbrands = set(brands)\nbrands = list(brands)\n\nprint(brands)\n\nbrands_clean = []\nfor brand in brands:\n    brand = brand[:-1]\n    brand = brand.lower()\n    brands_clean.append(brand)\ndel brands[0]\nprint(brands_clean)\n    \n'

# %%
# Out:
# [1 2 3]
